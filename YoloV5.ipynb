# %% [markdown]
# <a href="https://colab.research.google.com/github/EhsanDrn2207/Deep-Learning-/blob/main/YoloV5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Connection with google drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## **libraries**

# %%
# !python -m pip install --upgrade pip

# !pip install tensorflow

# !pip install tensorboard

# !pip install torch

# %%
import torch
from IPython.display import Image

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# ## **Install YoloV5**

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 16.73 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## **Use pre-trained Yolov5 for prediction**
#
# ---

# %%
# !python detect.py --weights yolov5m.pt --conf-thres 0.25 --source /content/gdrive/MyDrive/images/poeple2.jpg
# Out:
# detect: weights=['yolov5m.pt'], source=/content/gdrive/MyDrive/images/poeple2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 21172173 parameters, 0 gradients, 48.9 GFLOPs
# image 1/1 /content/gdrive/MyDrive/images/poeple2.jpg: 480x640 11 persons, 3 cars, 1 bus, 4 traffic lights, 1 handbag, 42.4ms
# Speed: 0.7ms pre-process, 42.4ms inference, 120.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7

# %%
Image('runs/detect/exp7/poeple2.jpg')

# %%
# !python detect.py --source /content/gdrive/MyDrive/images/poeple2.jpg --classes 0 9
# Out:
# detect: weights=yolov5s.pt, source=/content/gdrive/MyDrive/images/poeple2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=[0, 9], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 223MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/gdrive/MyDrive/images/poeple2.jpg: 480x640 11 persons, 4 traffic lights, 30.2ms
# Speed: 0.7ms pre-process, 30.2ms inference, 171.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
Image('runs/detect/exp8/poeple2.jpg')

# %% [markdown]
# ## **Use pre-trained Yolov5 for classification**
#
# ---

# %%
# !python classify/predict.py --weights yolov5s-cls.pt --source  /content/gdrive/MyDrive/images/fruit/9.jpg

# %% [markdown]
# ## **Use pre-trained Yolov5 for vidoes**
#
# ---

# %%
# !python detect.py --source /content/gdrive/MyDrive/videos/highway.mp4
