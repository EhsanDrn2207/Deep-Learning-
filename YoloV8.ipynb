# %% [markdown]
# <a href="https://colab.research.google.com/github/EhsanDrn2207/Deep-Learning-/blob/main/YoloV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Connection with google drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## **Install YoloV8**

# %%
# %cd
# Out:
# /root

# %%
! git clone https://github.com/autogyro/yolo-V8.git
# Out:
# Cloning into 'yolo-V8'...
# remote: Enumerating objects: 2723, done.
# remote: Total 2723 (delta 0), reused 0 (delta 0), pack-reused 2723 (from 1)
# Receiving objects: 100% (2723/2723), 1.41 MiB | 9.56 MiB/s, done.
# Resolving deltas: 100% (1855/1855), done.

# %%
# !ls
# Out:
# yolo-V8

# %%
# %cd /root/yolo-V8/
# Out:
# /root/yolo-V8

# %%
# !pip install -r requirements.txt

# %%
# !pip install ultralytics

# %%
# !pip install Ipython

# %%
import torch
from IPython.display import Image

# %% [markdown]
# ## **Implement YoloV8 for photoes**

# %%
# !ls /content/gdrive/MyDrive/images/Nima/
# Out:
#  apple.jpeg	      clock_detected.jpg       microwave.webp	     teddy-bear-detection.jpg
#  banana.webp	      clock.jpeg	       mouse.jpg	     teddy-bear.jpeg
#  bed.jpeg	      couch.webp	       orange.webp	     toaster.webp
#  book_1.jpg	      cup.webp		       oven.webp	     toilet.webp
#  book_2.webp	      dining_table.webp        pizza-detection.jpg   toothbrush.jpeg
#  broccoli.jpeg	      donut.webp	       pizza.jpeg	     tv_detected.jpg
#  cake_detected.jpg    fork.webp		      'potted plant.webp'    tv.jpeg
#  cake.jpeg	      hair_drier.jpg	       refrigerator.webp     vase.jpeg
#  carrot.webp	      hotdog.webp	       remote.jpg	    'wine glass.webp'
# 'cell phonnee.webp'  'keyboard & mouse.jpeg'   scissors.webp
#  chair_detected.jpg   knife.jpeg	       sink.webp
#  chair.jpeg	      laptop.jpeg	       spoon.webp

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.2 source="/content/gdrive/MyDrive/images/Nima/tv.jpeg" save=True
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/images/Nima/tv.jpeg: 448x640 1 couch, 1 tv, 220.1ms
# Speed: 9.8ms preprocess, 220.1ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict17
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('runs/detect/predict17/tv.jpg')

# %%
# !yolo task=detect mode=predict model=yolov8s.pt conf=0.2 source="/content/gdrive/MyDrive/images/Nima/tv.jpeg" save=True
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/images/Nima/tv.jpeg: 448x640 1 chair, 1 couch, 1 tv, 452.1ms
# Speed: 5.9ms preprocess, 452.1ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict18
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('runs/detect/predict18/tv.jpg')

# %%
# !yolo task=detect mode=predict model=yolov8m.pt conf=0.2 source="/content/gdrive/MyDrive/images/Nima/tv.jpeg" save=True
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/images/Nima/tv.jpeg: 448x640 1 couch, 1 tv, 1 remote, 1020.9ms
# Speed: 4.5ms preprocess, 1020.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict19
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('runs/detect/predict19/tv.jpg')

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.2 source="/content/gdrive/MyDrive/images/Nima/tv.jpeg" save=True
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8l summary (fused): 268 layers, 43,668,288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/images/Nima/tv.jpeg: 448x640 1 couch, 1 bed, 1 tv, 1 remote, 1951.1ms
# Speed: 5.9ms preprocess, 1951.1ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict20
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('runs/detect/predict20/tv.jpg')

# %%
# !yolo task=detect mode=predict model=yolov8x.pt conf=0.2 source="/content/gdrive/MyDrive/images/Nima/tv.jpeg" save=True
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8x summary (fused): 268 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/images/Nima/tv.jpeg: 448x640 1 chair, 1 couch, 1 tv, 1 laptop, 1 remote, 5710.4ms
# Speed: 7.9ms preprocess, 5710.4ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict21
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('runs/detect/predict21/tv.jpg')

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/gdrive/MyDrive/images/fire_hydrate.jpeg" save=True
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/images/fire_hydrate.jpeg: 640x448 1 person, 1 car, 1 bus, 1 fire hydrant, 180.8ms
# Speed: 4.6ms preprocess, 180.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict34
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## **Implement YoloV8 for videos**

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/gdrive/MyDrive/videos/street.mp4" save=True

# %% [markdown]
# ## **Segmentation**

# %%
# !yolo task=segment mode=predict model='yolov8l-seg.pt' conf=0.25 source="/content/gdrive/MyDrive/images/Booths-of-30-Tir-Street.jpg" save=True
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8l-seg summary (fused): 295 layers, 45,973,568 parameters, 0 gradients, 220.5 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/images/Booths-of-30-Tir-Street.jpg: 384x640 10 persons, 1 bicycle, 1 car, 2 motorcycles, 1 kite, 2037.1ms
# Speed: 2.7ms preprocess, 2037.1ms inference, 29.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/segment/predict10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model='yolov8n-seg.pt' conf=0.25 source="/content/gdrive/MyDrive/videos/coast.mp4" save=True
